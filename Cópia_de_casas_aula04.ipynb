# %% [markdown]
# <a href="https://colab.research.google.com/github/ossanlu/MonitoriaDS/blob/main/C%C3%B3pia_de_casas_aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# > Importando o DataSet

# %% [markdown]
# [Link para o DataSet](https://www.kaggle.com/datasets/rubenssjr/brasilian-houses-to-rent/data)

# %%
from google import colab
colab.drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/houses_to_rent_v2.csv') # Cole o coaminho para seu dataframe

# %% [markdown]
# # Pré-Processamemto

# %% [markdown]
# **Etapas:**
# - 1 - Visualização
# - 2 - Renomeação de Colunas
# - 3 - Imputação(Valores Faltando)
# - 4 - Tratamento de Textos
# - 5 - Normalização/Padronização

# %% [markdown]
# ## Visualização

# %%
# Informações gerais sobre o DataFrame
df.info()

# %%
# Resumo estatístico das colunas numéricas
df.describe()

# %%
# Verificar valores ausentes
df.isnull().sum()

# %% [markdown]
# ## Imputação

# %% [markdown]
# Decisões:
# - Média
#   - Desvio Padrão
# - Moda
# - Mediana

# %% [markdown]
# - Remoção Total: Remoção de todos os valores faltantes, importante para colunas inuteis.

# %%
df['floor'].value_counts()
# Out:
# floor
# -      2461
# 1      1081
# 2       985
# 3       931
# 4       748
# 5       600
# 6       539
# 7       497
# 8       490
# 9       369
# 10      357
# 11      303
# 12      257
# 13      200
# 14      170
# 15      147
# 16      109
# 17       96
# 18       75
# 19       53
# 20       44
# 21       42
# 25       25
# 23       25
# 22       24
# 26       20
# 24       19
# 27        8
# 28        6
# 29        5
# 32        2
# 35        1
# 46        1
# 301       1
# 51        1
# Name: count, dtype: int64

# %%
# Trocando string por null
df['floor'] = df['floor'].replace('-', np.nan)

# Decisão de remover valores faltantes
df.dropna(subset=['floor'], inplace=True)

df.isnull().sum()
# Out:
# city                   0
# area                   0
# rooms                  0
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8231 entries, 0 to 10690
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 8231 non-null   object
#  1   area                 8231 non-null   int64
#  2   rooms                8231 non-null   int64
#  3   bathroom             8231 non-null   int64
#  4   parking spaces       8231 non-null   int64
#  5   floor                8231 non-null   object
#  6   animal               8231 non-null   object
#  7   furniture            8231 non-null   object
#  8   hoa (R$)             8231 non-null   int64
#  9   rent amount (R$)     8231 non-null   int64
#  10  property tax (R$)    8231 non-null   int64
#  11  fire insurance (R$)  8231 non-null   int64
#  12  total (R$)           8231 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 900.3+ KB

# %%
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# 3                   17        1421
# 4                   11         836

# %% [markdown]
# ## Tratando colunas

# %% [markdown]
# > Em alguns casos, por questões de praticidade, a renomeação de colunas pode ser uma etapa a se considerar no pré-processamento

# %% [markdown]
# Por exemplo, é muito mais simples escrever `total` ao invés de `total (R$)`

# %%
import re # biblioteca para uso de regex

# Façam uma lista com as colunas a serem removido os elementos '(R$)'
colunas = ['hoa (R$)', 'rent amount (R$)', 'property tax (R$)', 'fire insurance (R$)', 'total (R$)']

for coluna in colunas:
    novo_nome = re.sub(r'[R$()]+', '', coluna) #essa linha serve para mudar o nome da coluna, retirando o R$
                                              #o uso desse (r <-'[R$()]+', '', coluna) serve para ignorar os comando de contrabarra '\' do python
    df.rename(columns={coluna : novo_nome}, inplace=True)

# Imprima as colunas
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa   rent amount   property tax   fire insurance   total
# 0      furnished  2065          3300            211               42    5618
# 1  not furnished  1200          4960           1750               63    7973
# 2  not furnished  1000          2800              0               41    3841
# 3  not furnished   270          1112             22               17    1421
# 4  not furnished     0           800             25               11     836

# %% [markdown]
# - Normalmente utilizamos regex para remoção de caracteres específicos em uma string.

# %% [markdown]
# - `[]` informa o conjunto de caracteres a ser substituido
# - `R$()` são os nossos alvos
# - `+` informa a substituição de uma ou mais ocorrências

# %%
# Imprima o resultado com a cabeça do DataFrame
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa   rent amount   property tax   fire insurance   total
# 0      furnished  2065          3300            211               42    5618
# 1  not furnished  1200          4960           1750               63    7973
# 2  not furnished  1000          2800              0               41    3841
# 3  not furnished   270          1112             22               17    1421
# 4  not furnished     0           800             25               11     836

# %% [markdown]
# ## Lidando com texto

# %% [markdown]
# > Por que categorizar dados?

# %% [markdown]
# A técnica mais usada é chamada **Label Encoding**, esta técninca envolve categorizar valores não numéricos, por exemplo:
#
# `homem = 1` e `mulher = 0`

# %%
# identificação da coluna
df[['animal', 'furniture']].value_counts()
# Out:
# animal  furniture
# 1       0            4771
#         1            1552
# 0       0            1208
#         1             700
# Name: count, dtype: int64

# %%
# Categorozação da coluna animais e furniture
df['animal'].replace({'acept': 1, 'not acept': 0}, inplace=True)

# Faça o mesmo com a coluna 'furniture'
df['furniture'].replace({'furnished': 1, 'not furnished' : 0}, inplace=True)

# %% [markdown]
# - 0 : Não
# - 1 : Sim

# %% [markdown]
# - Transformando coluna floor em inteiro

# %%
# Complete o código abaixo transformando a coluna 'floor' em númerico
df['floor'] = df['floor'].astype(int)

# %%
df.dtypes
# Out:
# city               object
# area                int64
# rooms               int64
# bathroom            int64
# parking spaces      int64
# floor               int64
# animal              int64
# furniture           int64
# hoa                 int64
# rent amount         int64
# property tax        int64
# fire insurance      int64
# total               int64
# dtype: object

# %%
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces  floor  animal  \
# 0     São Paulo    70      2         1               1      7       1
# 1     São Paulo   320      4         4               0     20       1
# 2  Porto Alegre    80      1         1               1      6       1
# 3  Porto Alegre    51      2         1               0      2       1
# 4     São Paulo    25      1         1               0      1       0
#
#    furniture  hoa   rent amount   property tax   fire insurance   total
# 0          1  2065          3300            211               42    5618
# 1          0  1200          4960           1750               63    7973
# 2          0  1000          2800              0               41    3841
# 3          0   270          1112             22               17    1421
# 4          0     0           800             25               11     836

# %% [markdown]
# # Exportando o DataFrame

# %% [markdown]
# > Com o DataFrame limpo, agora podemos exportar o mesmo para as etapas de visualização e modelagem.

# %%
df.to_csv('casas_limpo.csv', index=False)
